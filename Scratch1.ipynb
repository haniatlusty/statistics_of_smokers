# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("smoking.csv")

# %%
df
# Out:
#       Unnamed: 0  gender  age marital_status highest_qualification  \
# 0              1    Male   38       Divorced      No Qualification
# 1              2  Female   42         Single      No Qualification
# 2              3    Male   40        Married                Degree
# 3              4  Female   40        Married                Degree
# 4              5  Female   39        Married          GCSE/O Level
# ...          ...     ...  ...            ...                   ...
# 1686        1687    Male   22         Single      No Qualification
# 1687        1688  Female   49       Divorced      Other/Sub Degree
# 1688        1689    Male   45        Married      Other/Sub Degree
# 1689        1690  Female   51        Married      No Qualification
# 1690        1691    Male   31        Married                Degree
#
#      nationality ethnicity      gross_income     region smoke  amt_weekends  \
# 0        British     White    2,600 to 5,200  The North    No           NaN
# ...

# %% [markdown]
# From the description we can read that "amt_weekends" column describe the number of cigarettes smoked per day on weekends so as the column "amt_weekdays" means.The column "type" contains the type of cigarettes e.g. Packets, Hand-Rolled etc.
#
# The data contains 1691 observations and 12 variables that describe smoking habits a group of people from UK.

# %%
df.describe()
# Out:
#         Unnamed: 0          age  amt_weekends  amt_weekdays
# count  1691.000000  1691.000000    421.000000    421.000000
# mean    846.000000    49.836192     16.410926     13.750594
# std     488.293969    18.736851      9.892988      9.388292
# min       1.000000    16.000000      0.000000      0.000000
# 25%     423.500000    34.000000     10.000000      7.000000
# 50%     846.000000    48.000000     15.000000     12.000000
# 75%    1268.500000    65.500000     20.000000     20.000000
# max    1691.000000    97.000000     60.000000     55.000000

# %% [markdown]
# The average age of people from the experiment is 49.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'gender', 'age', 'marital_status',
#        'highest_qualification', 'nationality', 'ethnicity', 'gross_income',
#        'region', 'smoke', 'amt_weekends', 'amt_weekdays', 'type'],
#       dtype='object')

# %% [markdown]
# Firsty, we need to set the column index properly.

# %%
df = df.set_index("Unnamed: 0")

# %%
df[:50]
# Out:
#             gender  age marital_status highest_qualification nationality  \
# Unnamed: 0
# 1             Male   38       Divorced      No Qualification     British
# 2           Female   42         Single      No Qualification     British
# 3             Male   40        Married                Degree     English
# 4           Female   40        Married                Degree     English
# 5           Female   39        Married          GCSE/O Level     British
# 6           Female   37        Married          GCSE/O Level     British
# 7             Male   53        Married                Degree     British
# 8             Male   44         Single                Degree     English
# 9             Male   40         Single              GCSE/CSE     English
# 10          Female   41        Married      No Qualification     English
# 11            Male   72        Widowed      No Qualification     English
# 12            Male   49        Married      No Qualification     British
# ...

# %%
df.dtypes
# Out:
# gender                    object
# age                        int64
# marital_status            object
# highest_qualification     object
# nationality               object
# ethnicity                 object
# gross_income              object
# region                    object
# smoke                     object
# amt_weekends             float64
# amt_weekdays             float64
# type                      object
# dtype: object

# %%
sns.histplot(df["age"], stat = "density", color = "lightgreen", kde = True)
plt.vlines(max(df["age"]), ymin = 0, ymax = 0.02, color = "red", label = "Max age: {}".format(max(df["age"])))
plt.vlines(min(df["age"]), ymin = 0, ymax = 0.02, color = "yellow", label = "Min age: {}".format(min(df["age"])))
plt.title("The histogram of people's age")
plt.vlines(np.mean(df["age"]), ymin = 0, ymax = 0.02, label = "Average age: {}".format(int(np.mean(df["age"]))))

plt.legend()

# %%
x = np.linspace(-1,1)
sns.boxplot(y = df["age"], color = 'lightgreen')
plt.plot(x, [max(df["age"])]*50, color = "red", label = "max")
plt.plot(x, [min(df["age"])]*50, color = "orange", label = "min")
plt.plot(x, [np.median(df["age"])]*50, color = "green", label = "median")
plt.plot(x, [np.quantile(df["age"], 0.25)]*50, color = "blue", label = "quantile 0.25")
plt.plot(x, [np.quantile(df["age"], 0.75)]*50, color = "pink", label = "quantile 0.75")
plt.title("Boxplot that includes the description of basic statistics")
plt.legend()

# %%
df["gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df["smoke"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
amount_of_females = len(df[df["gender"]=="Female"])
amount_of_males = len(df[df["gender"]=="Male"])
genders = ["Female", "Male"]
colors = sns.color_palette('pastel')[0:2]
plt.pie(x = [amount_of_females, amount_of_males], labels = genders, colors = colors, autopct='%.0f%%');
plt.title("Genders of all")
# Out:
# Text(0.5, 1.0, 'Genders of all')

# %%
smokers = df[df["smoke"]=="Yes"]
plt.pie(x = [len(smokers[smokers["gender"]=="Female"]), len(smokers[smokers["gender"]=="Male"])], labels = genders, colors = colors, autopct='%.0f%%');
plt.title("Genders of smokers")
# Out:
# Text(0.5, 1.0, 'Genders of smokers')

# %%
df.columns
# Out:
# Index(['gender', 'age', 'marital_status', 'highest_qualification',
#        'nationality', 'ethnicity', 'gross_income', 'region', 'smoke',
#        'amt_weekends', 'amt_weekdays', 'type'],
#       dtype='object')

# %%
unique_columns = ["gender", "marital_status", "highest_qualification", "nationality", "ethnicity", "region"]

# %%
uniques = pd.DataFrame()
for column in unique_columns:
    uni = df[column].unique()
    df_uni = pd.DataFrame(uni, columns = [column])
    uniques = pd.concat([uniques, df_uni], axis = 1)
uniques
# Out:
#    gender marital_status highest_qualification nationality ethnicity  \
# 0    Male       Divorced      No Qualification     British     White
# 1  Female         Single                Degree     English     Mixed
# 2     NaN        Married          GCSE/O Level    Scottish     Black
# 3     NaN        Widowed              GCSE/CSE       Other   Refused
# 4     NaN      Separated      Other/Sub Degree       Welsh     Asian
# 5     NaN            NaN     Higher/Sub Degree       Irish   Chinese
# 6     NaN            NaN              ONC/BTEC     Refused   Unknown
# 7     NaN            NaN              A Levels     Unknown       NaN
#
#                    region
# 0               The North
# 1  Midlands & East Anglia
# 2                  London
# 3              South East
# 4              South West
# 5                   Wales
# 6                Scotland
# 7                     NaN

# %% [markdown]
# And now let's check if the unique values are similar to smokers.

# %%
uniques_smokers = pd.DataFrame()
for column in unique_columns:
    uni = smokers[column].unique()
    df_uni = pd.DataFrame(uni, columns = [column])
    uniques_smokers = pd.concat([uniques_smokers, df_uni], axis = 1)
uniques_smokers
# Out:
#    gender marital_status highest_qualification nationality ethnicity  \
# 0  Female         Single      No Qualification     British     White
# 1    Male        Married                Degree     English     Mixed
# 2     NaN       Divorced              GCSE/CSE       Welsh     Asian
# 3     NaN        Widowed          GCSE/O Level       Irish   Chinese
# 4     NaN      Separated      Other/Sub Degree    Scottish   Refused
# 5     NaN            NaN              A Levels       Other     Black
# 6     NaN            NaN              ONC/BTEC     Unknown   Unknown
# 7     NaN            NaN     Higher/Sub Degree     Refused       NaN
#
#                    region
# 0               The North
# 1  Midlands & East Anglia
# 2                  London
# 3              South East
# 4              South West
# 5                   Wales
# 6                Scotland
# 7                     NaN

# %%
uniques["gender"].isin(uniques_smokers["gender"])
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# Name: gender, dtype: bool

# %%
uniques["highest_qualification"].isin(uniques_smokers["highest_qualification"]).values
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True])

# %%
i = 0
for col in unique_columns:
    if True in uniques[col].isin(uniques_smokers[col]).values :
        print("{} column are both the same".format(col))
        i = i + 1
print("{} of {} colums comparing are the same".format(i, len(unique_columns)))
# Out:
# gender column are both the same
# marital_status column are both the same
# highest_qualification column are both the same
# nationality column are both the same
# ethnicity column are both the same
# region column are both the same
# 6 of 6 colums comparing are the same
